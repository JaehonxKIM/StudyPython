# %% [markdown]
# ## Python 과 Numpy의 차이점
#  - 행렬에 특화된 모듈이 numpy임

# %% [markdown]
# Pillow로 이미지 분석 & 리사이즈 (from PIL import Image,
#                     Image.open('pic/사진파일명))

# %%
from PIL import Image 
folderName='./pic/'
fileName='pic2.jpg'
img = Image.open(folderName + fileName)
img.resize((200,200))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x25D1BA7F7F0>

# %%
type(folderName)
# Out:
# str

# %% [markdown]
# 폴더 찾기

# %%
import os, glob
filter(os.path.isdir, glob.glob("c:/*"))
dataList= glob.glob("./*") #카멜표기법
for x in dataList: #객체할당
    print(x)


# for x in range(len(data_List)): #인덱스할당
#     print(dataList[0])
# Out:
# .\pic
# .\prcture_resize.ipynb

# %%
import os, glob
dataList = glob.glob('./*')

# %% [markdown]
# 파일 복사하기

# %%
from distutils.dir_util import copy_tree

copy_tree("./pic", "./pic복사본") #이미 있을때는 안됨
# Out:
# ['./pic복사\\pic1.jpg',
#  './pic복사\\pic2.jpg',
#  './pic복사\\sketch-g462ae211a_1920.jpg']
